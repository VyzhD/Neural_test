# %% [markdown]
# <a href="https://colab.research.google.com/github/VyzhD/Neural_test/blob/main/%D0%9F%D0%B5%D1%80%D0%B2%D1%8B%D0%B9_%D1%82%D0%B5%D1%81%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import utils


(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()


x_train = x_train.reshape(60000, 784)

x_train = x_train / 255

y_train = utils.to_categorical(y_train,10)

model = Sequential()
model.add(Dense(800,input_dim=784,activation="relu"))
model.add(Dense(10,activation="softmax"))

model.compile(loss = "categorical_crossentropy", optimizer="SGD", metrics=['accuracy'])

model.fit(x_train,y_train,batch_size=200,epochs=100,verbose=1)

print(model.summary())
predictions = model.predict(x_train)
print(predictions[0])

print(np.argmax(predictions))
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step
# Epoch 1/100
# 300/300 [==============================] - 1s 3ms/step - loss: 1.1157 - accuracy: 0.6679
# Epoch 2/100
# 300/300 [==============================] - 1s 3ms/step - loss: 0.7273 - accuracy: 0.7656
# Epoch 3/100
# 300/300 [==============================] - 1s 3ms/step - loss: 0.6377 - accuracy: 0.7943
# Epoch 4/100
# 300/300 [==============================] - 1s 3ms/step - loss: 0.5890 - accuracy: 0.8095
# Epoch 5/100
# 300/300 [==============================] - 1s 3ms/step - loss: 0.5569 - accuracy: 0.8184
# Epoch 6/100
# 300/300 [==============================] - 1s 3ms/step - loss: 0.5338 - accuracy: 0.8238
# Epoch 7/100
# 300/300 [==============================] - 1s 3ms/step - loss: 0.5160 - accuracy: 0.8289
# Epoch 8/100
# 300/300 [==============================] - 1s 3ms/step - loss: 0.5015 - accuracy: 0.8328
# Epoch 9/100
# ...

# %%
print(np.argmax(predictions[0]))
# Out:
# 9
